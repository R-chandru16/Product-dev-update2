# %%
import pandas as pd

# %%
import pandas as pd
import tabula
from tabula import read_pdf
from tabulate import tabulate

# %%
from numpy import *

# %%
# !pip install tabulate
# Out:
# Could not fetch URL https://pypi.org/simple/tabulate/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/tabulate/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1125)'))) - skipping
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1125)'))) - skipping
# ...

# %% [markdown]
# ## Convert Pdf into CSV

# %%
pd.set_option('display.max_rows', None)  
df1 = tabula.read_pdf(
     "C:/Users/Administrator/Desktop/Kanini Training/Untitled Folder/bankInput/SBFREEDOM_6088-unlocked.pdf",
    pages="all",
    lattice=True,
    pandas_options={"header": [1]},
    area=[0, 0, 100, 100],
    relative_area=True,
    multiple_tables=False,
    
)



# replace_nan = isnan(df1)
# df1[replace_nan] = 0

df1[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6fbd49323ce0> in <module>
# ----> 1 pd.set_option('display.max_rows', None)
#       2 df1 = tabula.read_pdf(
#       3      "C:/Users/Administrator/Desktop/Kanini Training/Untitled Folder/bankInput/SBFREEDOM_6088-unlocked.pdf",
#       4     pages="all",
#       5     lattice=True,
#
# NameError: name 'pd' is not defined

# %%
df1[0]["Date"]= pd.to_datetime(df1[0]["Date"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d5af8dc340df> in <module>
# ----> 1 df1[0]["Date"]= pd.to_datetime(df1[0]["Date"])
#
# NameError: name 'pd' is not defined

# %%
df1[0].to_csv('C:/Users/Administrator/Desktop/Kanini Training/Untitled Folder/bankOutput/updated1.csv') 
#,df1[0]["Date"])
           # this is path where file will be saved which is converted into csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b281a97d5e7b> in <module>
# ----> 1 df1[0].to_csv('C:/Users/Administrator/Desktop/Kanini Training/Untitled Folder/bankOutput/updated1.csv')
#       2 #,df1[0]["Date"])
#       3            # this is path where file will be saved which is converted into csv
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv ( 'C:/Users/Administrator/Desktop/Kanini Training/Untitled Folder/bankOutput/updated1.csv')
# replace_nan = isnan(df)
# df[replace_nan] = 0

data
#df=data.fillna(0)
#df=data.iloc[:-1,:]
#df
# Out:
#      Unnamed: 0        Date                Value Date  \
# 0             0  2021-01-04  04-JAN-2021\r01:02:52 PM
# 1             1  2021-01-06  06-JAN-2021\r05:08:38 PM
# 2             2  2021-01-07  07-JAN-2021\r10:06:48 AM
# 3             3  2021-01-07  07-JAN-2021\r11:03:44 AM
# 4             4  2021-01-07  07-JAN-2021\r11:07:46 AM
# 5             5  2021-01-14  14-JAN-2021\r03:12:10 PM
# 6             6  2021-01-15  15-JAN-2021\r07:03:37 PM
# 7             7  2021-01-16  16-JAN-2021\r08:50:54 PM
# 8             8  2021-01-16  16-JAN-2021\r08:55:14 PM
# 9             9  2021-01-16  16-JAN-2021\r09:56:09 PM
# 10           10  2021-01-16  16-JAN-2021\r09:57:20 PM
# 11           11  2021-01-18  18-JAN-2021\r08:04:48 PM
# 12           12  2021-01-18  18-JAN-2021\r08:04:50 PM
# 13           13  2021-01-22  22-JAN-2021\r09:18:05 PM
# 14           14  2021-01-22  22-JAN-2021\r09:38:17 PM
# 15           15  2021-01-23  23-JAN-2021\r05:03:35 AM
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# Date                 1
# Value Date           1
# Particulars          0
# Tran\rType           1
# Cheque\rDetails    230
# Withdrawals         76
# Deposits           153
# Balance              1
# dtype: int64

# %%
data['Tran\rType'].value_counts().rename_axis("TranType").reset_index(name="counts")
# Out:
#   TranType  counts
# 0        D     153
# 1        C      76

# %%
df= pd.DataFrame(data, columns= ['Date','Withdrawals'])
#data

#df=data.iloc[:-1,:]
#df

# %%
#the below graph give frequency count of per withdrawal amount
import seaborn as sns

df4stock = df.copy()

#Visualization
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x=df4stock.index, y="Withdrawals", data=df4stock, estimator=None);
fig.gca().ticklabel_format(style='plain', axis='y')

# %%
db = pd.DataFrame(data, columns= ['Date','Deposits'])
db
# Out:
#            Date  Deposits
# 0    2021-01-04       NaN
# 1    2021-01-06       NaN
# 2    2021-01-07       NaN
# 3    2021-01-07       NaN
# 4    2021-01-07       NaN
# 5    2021-01-14       NaN
# 6    2021-01-15       NaN
# 7    2021-01-16     300.0
# 8    2021-01-16     100.0
# 9    2021-01-16     100.0
# 10   2021-01-16       NaN
# 11   2021-01-18      40.0
# 12   2021-01-18       NaN
# 13   2021-01-22       NaN
# 14   2021-01-22     800.0
# 15   2021-01-23       NaN
# 16   2021-01-30     370.0
# 17   2021-02-08       NaN
# 18   2021-02-08       9.0
# 19   2021-02-15       NaN
# 20   2021-02-25     750.0
# 21   2021-02-27       NaN
# 22   2021-02-27       NaN
# 23   2021-02-27     100.0
# 24   2021-02-27       NaN
# 25   2021-03-01    2000.0
# 26   2021-03-01       NaN
# 27   2021-03-03       NaN
# 28   2021-03-05       NaN
# 29   2021-03-06       NaN
# 30   2021-03-06       NaN
# 31   2021-03-07       NaN
# 32   2021-03-08       NaN
# 33   2021-03-09     500.0
# ...

# %%
#Frequency of Deposit amount
df=db.iloc[:-1,:]
df.plot.bar(x='Date', y='Deposits', rot=0)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from datetime import datetime

def mdy_to_ymd(Date):return datetime.strptime(Date, '%b %d, %Y').strftime('%Y-%m-%d')

# %%
db["Date"]= pd.to_datetime(db["Date"])
  
# info of data
db.info()
  
# display
db
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      229 non-null    datetime64[ns]
#  1   Deposits  77 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.7 KB
#           Date  Deposits
# 0   2021-01-04       NaN
# 1   2021-01-06       NaN
# 2   2021-01-07       NaN
# 3   2021-01-07       NaN
# 4   2021-01-07       NaN
# 5   2021-01-14       NaN
# 6   2021-01-15       NaN
# 7   2021-01-16     300.0
# 8   2021-01-16     100.0
# 9   2021-01-16     100.0
# 10  2021-01-16       NaN
# 11  2021-01-18      40.0
# 12  2021-01-18       NaN
# 13  2021-01-22       NaN
# 14  2021-01-22     800.0
# 15  2021-01-23       NaN
# 16  2021-01-30     370.0
# 17  2021-02-08       NaN
# 18  2021-02-08       9.0
# 19  2021-02-15       NaN
# 20  2021-02-25     750.0
# 21  2021-02-27       NaN
# 22  2021-02-27       NaN
# ...

# %%
#df = df.astype({"Deposits": float})

# %%
# df.index = df['Date']

# %%
# plt.figure(figsize=(5,7))
# plt.plot(df["Deposits"],label= 'Deposits',color='green',linestyle='--',linewidth=4)

# %%
#data = pd.DataFrame(df, columns= ['Date','Withdrawals'])

#df=data.iloc[:-1,:]
#df
#df_order = pd.read_csv('C:/Users/Administrator/Desktop/Kanini Training/Untitled Folder/bankOutput/updated1.csv', parse_dates=['Date'])
#pd.to_datetime
#g = df_order.groupby(pd.Grouper(freq="M")) 
per = df1[0].Date.dt.to_period("M")

# %%
#Month wise Data
g = df1[0].groupby(per)
g.sum()
# Out:
#          Cheque\rDetails  Withdrawals  Deposits     Balance
# Date
# 2021-01              0.0      1670.20    1710.0    20452.36
# 2021-02              0.0      1239.00     859.0     9381.64
# 2021-03              0.0      7500.69    7508.0    50925.06
# 2021-04              0.0      4755.00    4773.0    36902.85
# 2021-06              0.0      7025.00    7007.0    13018.34
# 2021-07              0.0      1901.50    2000.0    20112.85
# 2021-08              0.0       149.00     100.0     2265.78
# 2021-09              0.0      1460.00    1507.0     6160.56
# 2021-10              0.0      1964.00    2281.0    13742.90
# 2021-11              0.0     26498.80   26079.0   148616.11
# 2021-12              0.0    139455.80  159436.0  1133327.90

# %%
#Day wise Withdrawals
g.plot.bar(x="Date", y="Withdrawals", color='blue');

# %%
#Daily Balance count
g.plot.bar(x="Date", y="Balance", color='red');

# %% [markdown]
# ## Histogram:
# ### The graph give the idea about deposite frequency

# %%
plt.hist(df['Deposits'])
# Out:
# (array([70.,  2.,  1.,  0.,  0.,  1.,  1.,  0.,  0.,  1.]),
#  array([1.00000e+00, 5.00090e+03, 1.00008e+04, 1.50007e+04, 2.00006e+04,
#         2.50005e+04, 3.00004e+04, 3.50003e+04, 4.00002e+04, 4.50001e+04,
#         5.00000e+04]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Divided the Deposite Data randomly to get the clear view of deposite frequency

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt 
x_1, x_2 = train_test_split(df,
                                                    train_size=0.5 
                                                    #random_state=42,
                                                    )


print(f"First Half:\n{x_1}")
print(f"Second half:\n{x_2}")

#X_train 
#plt.hist(df['Deposits'])
# Out:
# First Half:
#                   Date  Deposits
# Date
# 2021-11-07  2021-11-07       NaN
# 2021-01-18  2021-01-18       NaN
# 2021-02-27  2021-02-27     100.0
# 2021-12-20  2021-12-20       NaN
# 2021-12-21  2021-12-21       NaN
# 2021-04-05  2021-04-05    1250.0
# 2021-12-20  2021-12-20       NaN
# 2021-12-04  2021-12-04       NaN
# 2021-09-29  2021-09-29       7.0
# 2021-12-20  2021-12-20       NaN
# 2021-04-22  2021-04-22       NaN
# 2021-07-18  2021-07-18       NaN
# 2021-12-04  2021-12-04     500.0
# 2021-12-09  2021-12-09       NaN
# 2021-12-04  2021-12-04       NaN
# 2021-12-20  2021-12-20       NaN
# 2021-12-01  2021-12-01       NaN
# 2021-01-18  2021-01-18      40.0
# 2021-11-07  2021-11-07    2000.0
# 2021-12-17  2021-12-17       NaN
# 2021-11-07  2021-11-07    2000.0
# 2021-11-13  2021-11-13       NaN
# 2021-03-09  2021-03-09     500.0
# 2021-03-22  2021-03-22       NaN
# 2021-04-06  2021-04-06       NaN
# 2021-11-30  2021-11-30       NaN
# ...

# %% [markdown]
# ### First Half

# %%
plt.hist(x_1['Deposits'])
plt.xlabel('Deposits')
plt.ylabel('Frequnecy of Transcations')
# Out:
# Text(0, 0.5, 'Frequnecy of Transcations')

# %% [markdown]
# ### Second Half

# %%
plt.hist(x_2['Deposits'])
plt.xlabel('Deposists')
plt.ylabel('Frequnecy of Transcations')
# Out:
# Text(0, 0.5, 'Frequnecy of Transcations')

# %%
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv ( 'C:/Users/Administrator/Desktop/Kanini Training/Untitled Folder/bankOutput/updated1.csv')

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt 
x_1, x_2 = train_test_split(df,
                                                    train_size=0.5 
                                                    #random_state=42,
                                                    )


print(f"First Half:\n{x_1}")
print(f"Second half:\n{x_2}")
# Out:
# First Half:
#      Unnamed: 0        Date                Value Date  \
# 119         119  2021-11-07  07-NOV-2021\r05:38:43 PM
# 170         170  2021-12-03  03-DEC-2021\r09:50:34 AM
# 198         198  2021-12-09  09-DEC-2021\r03:42:56 PM
# 163         163  2021-12-01  01-DEC-2021\r12:41:22 PM
# 124         124  2021-11-08  08-NOV-2021\r09:22:26 PM
# 195         195  2021-12-09  09-DEC-2021\r11:46:31 AM
# 80           80  2021-07-07  07-JUL-2021\r04:42:35 AM
# 82           82  2021-07-09  09-JUL-2021\r07:48:18 AM
# 179         179  2021-12-04  04-DEC-2021\r04:27:22 PM
# 43           43  2021-03-18  18-MAR-2021\r02:29:05 PM
# 108         108  2021-10-29  29-OCT-2021\r03:13:31 PM
# 214         214  2021-12-20  20-DEC-2021\r05:03:02 PM
# 189         189  2021-12-06  06-DEC-2021\r05:08:56 PM
# 210         210  2021-12-20  20-DEC-2021\r01:23:38 PM
# 50           50  2021-03-22  22-MAR-2021\r03:18:44 AM
# 172         172  2021-12-03  03-DEC-2021\r08:44:21 PM
# ...

# %%
plt.figure(figsize=(9,6))
plt.bar(x=db['Date'],height=df['Withdrawals'],color='Green')
plt.bar(x=db['Date'],height=df['Deposits'],color='blue')
plt.xticks(rotation= 45)
plt.title('Bar chart of Amount Withdrawals or Deposits')
plt.xlabel('Date',fontsize=13)
plt.ylabel('Amount',fontsize=13)
# Out:
# Text(0, 0.5, 'Amount')
